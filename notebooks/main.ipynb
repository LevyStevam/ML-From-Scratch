# %% [markdown]
# ## Teste da regressão linear GD

# %%
import numpy as np
import matplotlib.pyplot as plt

from models.linear_regression.linear_regression_gd import LinearRegressionGD

# %%
data = np.loadtxt('../data/processed/artificial1d.csv', delimiter=",")

X = data[:,0:1]
y = data[:,1]

# %%
linear_regression_gd = LinearRegressionGD(w0=0.0, w1=0.0)
linear_regression_gd.fit(X, y, epochs=250, learning_rate=0.1, plot_learning_curve=True)

# %%
predictions = linear_regression_gd.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Dados', alpha=0.6)

plt.plot(X, predictions, color='red', label='Reta de regressão')

plt.xlabel('Altura')
plt.ylabel('Comprimento do cateter')
plt.legend()
plt.show()

# %% [markdown]
# ## Teste da regressão linear SGD

# %%
from models.linear_regression.linear_regression_sgd import LinearRegressionSGD

# %%
linear_regression_sgd = LinearRegressionSGD(w0=0.0, w1=0.0)
linear_regression_sgd.fit(X, y, epochs=100, learning_rate=0.01, plot_learning_curve=True)

# %%
predictions = linear_regression_sgd.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Dados', alpha=0.6)

plt.plot(X, predictions, color='red', label='Reta de regressão')

plt.xlabel('Altura')
plt.ylabel('Comprimento do cateter')
plt.legend()
plt.show()

# %% [markdown]
# ## Teste da regressão linear OLS

# %%
from models.linear_regression.linear_regression_ols import LinearRegressionOLS

# %%
model = LinearRegressionOLS()

# %%
model.fit(X,y)

# %%
model.w
# Out:
# array([0.06761792, 1.57486517])

# %%
predictions = linear_regression_gd.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Dados', alpha=0.6)

plt.plot(X, predictions, color='red', label='Reta de regressão')

plt.xlabel('Altura')
plt.ylabel('Comprimento do cateter')
plt.legend()
plt.show()
