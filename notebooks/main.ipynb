# %% [markdown]
# ## Teste da regressão linear GD

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from models.linear_regression.linear_regression_gd import LinearRegressionGD

# %%
df = pd.read_csv('../data/processed/artificial1d.csv', delimiter=",")

X, y = df.iloc[:, 0], df.iloc[:, 1]

# %%
linear_regression_gd = LinearRegressionGD()
linear_regression_gd.fit(X, y, epochs=1000, learning_rate=0.01, plot_learning_curve=True)

# %%
X_test = np.random.uniform(-1, 1, 1000)

# %%
predictions = linear_regression_gd.predict(X_test)

# %%
plt.scatter(X, y, color='blue', label='Dados', alpha=0.6)

plt.plot(X_test, predictions, color='red', label='Reta de regressão')

plt.xlabel('Altura')
plt.ylabel('Comprimento do cateter')
plt.legend()
plt.show()

# %% [markdown]
# ## Teste da regressão linear SGD

# %%
from models.linear_regression.linear_regression_sgd import LinearRegressionSGD

# %%
linear_regression_sgd = LinearRegressionSGD()
linear_regression_sgd.fit(X, y, epochs=80, learning_rate=0.01, plot_learning_curve=True)

# %%
predictions = linear_regression_sgd.predict(X_test)

# %%
plt.scatter(X, y, color='blue', label='Dados', alpha=0.6)

plt.plot(X_test, predictions, color='red', label='Reta de regressão')

plt.xlabel('Altura')
plt.ylabel('Comprimento do cateter')
plt.legend()
plt.show()

# %% [markdown]
# ## Teste da regressão linear OLS

# %%
from models.linear_regression.linear_regression_ols import LinearRegressionOLS

# %%
model = LinearRegressionOLS()

# %%
model.fit(X.to_numpy(),y.to_numpy())

# %%
model.w
# Out:
# array([0.08956111, 1.51328267])

# %%
predictions = linear_regression_gd.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Dados', alpha=0.6)

plt.plot(X, predictions, color='red', label='Reta de regressão')

plt.xlabel('Altura')
plt.ylabel('Comprimento do cateter')
plt.legend()
plt.show()
